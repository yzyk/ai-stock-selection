# %%
import sys
sys.path.append('./Stlearn')
from Stlearn.Factory import *
from Stlearn.Portfolio import *
from Stlearn.Data import *

# %%
d = copy.deepcopy(data.X_train)
num_stocks = Constant.NUM_STOCKS
num_dates = int(d.shape[0] / num_stocks)
other_dims = d.shape[1:]
d = d.reshape(num_stocks, num_dates, *other_dims)
d = np.transpose(d, tuple([1, 0] + list(range(2, d.ndim))))
d.shape
# Out:
# (44, 488, 60, 152)

# %%
autof = LSTMAutoRegressorFactory('2020-01-01', '2020-06-01', '2020-07-01', '2020-08-01', 60)
data = autof.create_data()
model = autof.create_model()
model.fit(data)
# Out:
# X_train shape: (21472, 60, 152)
# y_train shape: (21472, 20, 1)
# X_valid shape: (10736, 60, 152)
# y_valid shape: (10736, 20, 1)
# X_test shape: (10736, 60, 152)
# y_test shape: (10736, 20, 1)
# Epoch 1/10
# 2022-12-02 16:17:40.266397: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# ---------------------------------------------------
# ---------------------------------------------------
# 671/671 [==============================] - 16s 23ms/step - loss: 9.3336e-04 - mean_squared_error: 9.3336e-04 - weighted_mean_squared_error: 9.3336e-04 - val_loss: 4.7967e-04 - val_mean_squared_error: 4.7967e-04 - val_weighted_mean_squared_error: 4.7967e-04
# Epoch 2/10
# 671/671 [==============================] - 15s 22ms/step - loss: 7.9357e-04 - mean_squared_error: 7.9357e-04 - weighted_mean_squared_error: 7.9357e-04 - val_loss: 4.7285e-04 - val_mean_squared_error: 4.7285e-04 - val_weighted_mean_squared_error: 4.7285e-04
# Epoch 3/10
# ...

# %%
import sys
sys.path.append('./Stlearn')
from Stlearn.Factory import *
from Stlearn.Portfolio import *
from Stlearn.Data import *
import Constant

autof = LSTMAutoRegressorFactory('2020-01-01', '2020-06-01', '2020-07-01', '2020-08-01', 1)
data1 = autof.create_data()
data = ThreeDimUnWinDataByDateByStockByFeature('2020-01-01', '2020-06-01', '2020-07-01', '2020-08-01')
# Out:
# X_train shape: (51279, 1, 152)
# y_train shape: (51279,)
# X_valid shape: (10976, 1, 152)
# y_valid shape: (10976,)
# X_test shape: (10975, 1, 152)
# y_test shape: (10975,)
# X_train shape: (103, 488, 152)
# y_train shape: (103, 488, 1)
# X_valid shape: (22, 488, 152)
# y_valid shape: (22, 488, 1)
# X_test shape: (22, 488, 152)
# y_test shape: (22, 488, 1)

# %%
data = ThreeDimUnWinDataByDateByStockByFeature('2019-01-01', '2020-06-01', '2020-07-01', '2020-08-01')
# Out:
# X_train shape: (355, 488, 152)
# y_train shape: (355, 488, 1)
# X_valid shape: (22, 488, 152)
# y_valid shape: (22, 488, 1)
# X_test shape: (22, 488, 152)
# y_test shape: (22, 488, 1)

# %%
import sys
sys.path.append('./Stlearn')
from Stlearn.Factory import *
from Stlearn.Portfolio import *
from Stlearn.Data import *
import Constant

data = FourDimWinDataByDateByWinByStockByFeature('2019-06-01', '2020-06-01', '2020-07-01', '2020-08-01', Constant.WIN_SIZE)
model = ConditionalVariationAutoEncoderModel('a')
# Out:
# X_train shape: (222, 30, 488, 152)
# y_train shape: (222, 20, 488, 1)
# X_valid shape: (22, 30, 488, 152)
# y_valid shape: (22, 20, 488, 1)
# X_test shape: (22, 30, 488, 152)
# y_test shape: (22, 20, 488, 1)

# %%
model.fit(data)
# Out:
# Epoch 1/10
# 2022-12-03 15:31:23.379494: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 7/7 [==============================] - 52s 5s/step - loss: 0.0401 - mean_squared_error: 0.0401 - weighted_mean_squared_error: 0.0401 - val_loss: 0.0371 - val_mean_squared_error: 0.0371 - val_weighted_mean_squared_error: 0.0371
# Epoch 2/10
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 model.fit(data)
#
# File ~/Library/CloudStorage/OneDrive-Personal/capstone/Deliverable/project/./Stlearn/Model.py:293, in ConditionalVariationAutoEncoderModel.fit(self, data)
#     291 X_train, y_train = data.get_train()
#     292 X_val, y_val = data.get_val()
# --> 293 history_ = self._model.fit([X_train, y_train], y_train,
#     294                            epochs=Constant.MAX_EPOCHS,
# ...

# %%
import sys
sys.path.append('./Stlearn')
from Stlearn.Factory import *
from Stlearn.Portfolio import *
from Stlearn.Data import *
import Constant

data = ThreeDimUnWinDataByDateByStockByFeature('2019-06-01', '2020-06-01', '2020-07-01', '2020-08-01')
model = StandardVariationAutoEncoderModel('a')
# Out:
# X_train shape: (251, 488, 152)
# y_train shape: (251, 488, 1)
# X_valid shape: (22, 488, 152)
# y_valid shape: (22, 488, 1)
# X_test shape: (22, 488, 152)
# y_test shape: (22, 488, 1)

# %%
model.fit(data)
# Out:
# Epoch 1/10
# 2022-12-03 16:05:54.014440: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 8/8 - 2s - loss: 0.4825 - mean_squared_error: 0.4825 - weighted_mean_squared_error: 0.4825 - val_loss: 0.4813 - val_mean_squared_error: 0.4814 - val_weighted_mean_squared_error: 0.4814 - 2s/epoch - 200ms/step
# Epoch 2/10
# 8/8 - 0s - loss: 0.4814 - mean_squared_error: 0.4813 - weighted_mean_squared_error: 0.4813 - val_loss: 0.4774 - val_mean_squared_error: 0.4775 - val_weighted_mean_squared_error: 0.4775 - 404ms/epoch - 50ms/step
# Epoch 3/10
# 8/8 - 0s - loss: 0.4803 - mean_squared_error: 0.4804 - weighted_mean_squared_error: 0.4804 - val_loss: 0.4879 - val_mean_squared_error: 0.4880 - val_weighted_mean_squared_error: 0.4880 - 403ms/epoch - 50ms/step
# Epoch 4/10
# ...

# %%
import sys
sys.path.append('./Stlearn')
from Stlearn.Factory import *
from Stlearn.Portfolio import *
from Stlearn.Data import *
import Constant


data2 = ThreeDimWinDataByStockDateByWinByFeature('2020-01-06', '2020-06-01', '2020-07-01', '2020-08-01', Constant.WIN_SIZE, Constant.FORWARD_STEPS_SIZE)
data3 = FourDimWinDataByDateByWinByStockByFeature('2020-01-06', '2020-06-01', '2020-07-01', '2020-08-01', Constant.WIN_SIZE, Constant.FORWARD_STEPS_SIZE)
# Out:
# C:\Users\yzyan\anaconda3\lib\site-packages\scipy\__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "
# X_train shape: (35136, 30, 152)
# y_train shape: (35136, 15, 1)
# X_valid shape: (10736, 30, 152)
# y_valid shape: (10736, 15, 1)
