# %%
import sys
sys.path.append('./Stlearn')
from Stlearn.Factory import *
from Stlearn.Portfolio import *
from Stlearn.Data import *

# %%
autof = LSTMAutoRegressorFactory('2020-01-01', '2020-06-01', '2020-07-01', '2020-08-01', 60)
data = autof.create_data()
model = autof.create_model()
model.fit(data)
# Out:
# X_train shape: (21856, 60, 152)
# y_train shape: (21856,)
# X_valid shape: (10958, 60, 152)
# y_valid shape: (10958,)
# X_test shape: (10975, 60, 152)
# y_test shape: (10975,)
# Epoch 1/10
# WARNING:tensorflow:AutoGraph could not transform <bound method LSTMAutoRegressor.call of <Prototype.LSTMAutoRegressor object at 0x000001D4E2124D60>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method LSTMAutoRegressor.call of <Prototype.LSTMAutoRegressor object at 0x000001D4E2124D60>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 683/683 [==============================] - 17s 26ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - weighted_mean_squared_error: 0.0010 - val_loss: 6.2847e-04 - val_mean_squared_error: 6.2847e-04 - val_weighted_mean_squared_error: 6.2847e-04
# Epoch 2/10
# 683/683 [==============================] - 17s 25ms/step - loss: 9.2760e-04 - mean_squared_error: 9.2760e-04 - weighted_mean_squared_error: 9.2760e-04 - val_loss: 6.4501e-04 - val_mean_squared_error: 6.4501e-04 - val_weighted_mean_squared_error: 6.4501e-04
# Epoch 3/10
# 683/683 [==============================] - 18s 26ms/step - loss: 9.1633e-04 - mean_squared_error: 9.1633e-04 - weighted_mean_squared_error: 9.1633e-04 - val_loss: 6.2607e-04 - val_mean_squared_error: 6.2607e-04 - val_weighted_mean_squared_error: 6.2607e-04
# Epoch 4/10
# 683/683 [==============================] - 19s 28ms/step - loss: 8.9569e-04 - mean_squared_error: 8.9569e-04 - weighted_mean_squared_error: 8.9569e-04 - val_loss: 6.0576e-04 - val_mean_squared_error: 6.0576e-04 - val_weighted_mean_squared_error: 6.0576e-04
# Epoch 5/10
# 683/683 [==============================] - 19s 27ms/step - loss: 8.7537e-04 - mean_squared_error: 8.7537e-04 - weighted_mean_squared_error: 8.7537e-04 - val_loss: 6.0757e-04 - val_mean_squared_error: 6.0757e-04 - val_weighted_mean_squared_error: 6.0757e-04
# Epoch 6/10
# 683/683 [==============================] - 19s 27ms/step - loss: 8.6070e-04 - mean_squared_error: 8.6070e-04 - weighted_mean_squared_error: 8.6070e-04 - val_loss: 6.0159e-04 - val_mean_squared_error: 6.0159e-04 - val_weighted_mean_squared_error: 6.0159e-04
# Epoch 7/10
# 683/683 [==============================] - 19s 28ms/step - loss: 8.4437e-04 - mean_squared_error: 8.4437e-04 - weighted_mean_squared_error: 8.4437e-04 - val_loss: 6.1915e-04 - val_mean_squared_error: 6.1915e-04 - val_weighted_mean_squared_error: 6.1915e-04
# Epoch 8/10
# 683/683 [==============================] - 18s 26ms/step - loss: 8.2704e-04 - mean_squared_error: 8.2704e-04 - weighted_mean_squared_error: 8.2704e-04 - val_loss: 6.0652e-04 - val_mean_squared_error: 6.0652e-04 - val_weighted_mean_squared_error: 6.0652e-04
# Epoch 9/10
# 683/683 [==============================] - 18s 26ms/step - loss: 8.1475e-04 - mean_squared_error: 8.1475e-04 - weighted_mean_squared_error: 8.1475e-04 - val_loss: 6.1466e-04 - val_mean_squared_error: 6.1466e-04 - val_weighted_mean_squared_error: 6.1466e-04
# Epoch 10/10
# 683/683 [==============================] - 18s 27ms/step - loss: 7.9546e-04 - mean_squared_error: 7.9546e-04 - weighted_mean_squared_error: 7.9546e-04 - val_loss: 6.5830e-04 - val_mean_squared_error: 6.5830e-04 - val_weighted_mean_squared_error: 6.5830e-04
